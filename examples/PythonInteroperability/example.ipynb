# %% [markdown]
# ## Install pythonnet

# %%
#pip install -U pythonnet

# %%
import os
import sys
from pythonnet import load
load("coreclr")
import clr  # noqa: E402
sys.path.append(os.path.abspath(r".\csProject\bin\Release\net10.0\publish"))
clr.AddReference("HEAL.HeuristicLib.Core") # type: ignore

# %%
from HEAL.HeuristicLib.Genotypes.Vectors import RealVector  # type: ignore
from System import Array, Double # type: ignore
vector = RealVector(Array[Double]([3.0]))
print(vector[0])
# Out:
# 3.0
